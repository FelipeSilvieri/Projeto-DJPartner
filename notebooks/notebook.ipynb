# %%
import pandas as pd

# %%
fisher = pd.read_csv('fisher.csv')
fisher['date'] = pd.to_datetime(fisher['date']) 
fisher.head(10)
# Out:
#                                                 name  \
# 0  FISHER @ kineticFIELD, EDC Orlando, United States
# 1  FISHER @ Zamna Mexico, Hipódromo De Las Americ...
# 2  Chris Lake & FISHER @ Under Construction, Holl...
# 3  FISHER @ The Palms, CRSSD Festival Fall, Unite...
# 4        FISHER @ TAO Beach Las Vegas, United States
# 5  FISHER @ Sutro, Outside Lands San Francisco, U...
# 6  FISHER @ BBC Radio 1 In Ibiza (528 Ibiza, Spai...
# 7  Joel Corry & Imanbek & FISHER + More - 1LIVE D...
# 8  FISHER @ Desert Valley Stage, Parookaville, Ge...
# 9        FISHER @ Piknic Électronik Montreal, Canada
#
#                                                 link       date  \
# 0  https://www.1001tracklists.com/tracklist/2mbh8... 2023-11-12
# 1  https://www.1001tracklists.com/tracklist/18hhu... 2023-10-29
# 2  https://www.1001tracklists.com/tracklist/16mv7... 2023-10-21
# 3  https://www.1001tracklists.com/tracklist/2by3d... 2023-09-24
# ...

# %%
vintage = pd.read_csv('vintage_culture.csv')
vintage['date'] = pd.to_datetime(vintage['date'])
vintage.head(10)
# Out:
#                                                 name  \
# 0                Vintage Culture - Culture Shock 115
# 1    Vintage Culture - One World Radio Residency 024
# 2                Vintage Culture - Culture Shock 114
# 3                Vintage Culture - Culture Shock 113
# 4                  Vintage Culture - Triple J Mix Up
# 5                Vintage Culture - Culture Shock 112
# 6  Vintage Culture @ Thunder Machine, Vintage Is ...
# 7                Vintage Culture - Culture Shock 111
# 8    Vintage Culture - One World Radio Residency 023
# 9  Vintage Culture & ANNA @ Core Stage, Tomorrowl...
#
#                                                 link       date  \
# 0  https://www.1001tracklists.com/tracklist/17ktf... 2023-11-17
# 1  https://www.1001tracklists.com/tracklist/2p63f... 2023-11-17
# 2  https://www.1001tracklists.com/tracklist/2b0g0... 2023-11-10
# 3  https://www.1001tracklists.com/tracklist/2vqnn... 2023-11-04
# ...

# %%
display(vintage['link'][vintage['date'] >= '2023-10-27'])
# Out:
# 0    https://www.1001tracklists.com/tracklist/17ktf...
# 1    https://www.1001tracklists.com/tracklist/2p63f...
# 2    https://www.1001tracklists.com/tracklist/2b0g0...
# 3    https://www.1001tracklists.com/tracklist/2vqnn...
# 4    https://www.1001tracklists.com/tracklist/2rzfw...
# 5    https://www.1001tracklists.com/tracklist/rr16z...
# Name: link, dtype: object

# %%
vintage.sort_values(by='date', inplace=True, ascending=False)
display(vintage)
# Out:
#                                                  name  \
# 0                 Vintage Culture - Culture Shock 115
# 1     Vintage Culture - One World Radio Residency 024
# 2                 Vintage Culture - Culture Shock 114
# 3                 Vintage Culture - Culture Shock 113
# 4                   Vintage Culture - Triple J Mix Up
# 5                 Vintage Culture - Culture Shock 112
# 6   Vintage Culture @ Thunder Machine, Vintage Is ...
# 7                 Vintage Culture - Culture Shock 111
# 8     Vintage Culture - One World Radio Residency 023
# 9   Vintage Culture & ANNA @ Core Stage, Tomorrowl...
# 10                Vintage Culture - Culture Shock 110
# 11                Vintage Culture - Culture Shock 109
# 12                Vintage Culture - Culture Shock 108
# 13                Vintage Culture - Culture Shock 107
# 15    Vintage Culture - One World Radio Residency 022
# 14                Vintage Culture - Culture Shock 106
# ...

# %%
martin = pd.read_csv('martin_garrix.csv')
martin.head(10)
# Out:
#                                                 name  \
# 0         Martin Garrix - The Martin Garrix Show 480
# 1         Martin Garrix - The Martin Garrix Show 479
# 2                       Martin Garrix @ H-ONE, China
# 3  Martin Garrix @ VAC Vision & Colour Music Fest...
# 4         Martin Garrix - The Martin Garrix Show 478
# 5  Martin Garrix @ Formula 1 Grand Prix Autódromo...
# 6         Martin Garrix - The Martin Garrix Show 477
# 7  Martin Garrix @ IDEM (All Ages Show), RAI, Ams...
# 8         Martin Garrix - The Martin Garrix Show 476
# 9  Martin Garrix @ IDEM (18+ Show), RAI, Amsterda...
#
#                                                 link        date  \
# 0  https://www.1001tracklists.com/tracklist/1w1g7...  2023-11-17
# 1  https://www.1001tracklists.com/tracklist/1jvst...  2023-11-10
# 2  https://www.1001tracklists.com/tracklist/x9x2j...  2023-11-04
# 3  https://www.1001tracklists.com/tracklist/1t7yv...  2023-11-04
# ...

# %%
hardwell = pd.read_csv('hardwell.csv')
display(hardwell)
# Out:
#                                                  name  \
# 0                      Hardwell - Hardwell On Air 502
# 1               Hardwell - Amsterdam Dance Event 2023
# 2                      Hardwell - Hardwell On Air 501
# 3   Hardwell @ Revealed, Q-Factory, Amsterdam Danc...
# 4   Hardwell @ Radio 538 DJ HOTEL (Amsterdam Dance...
# 5   Hardwell & W&W @ Rave Culture Showcase, Q-Fact...
# 6    Hardwell @ Mainstage, Ultra Music Festival Japan
# 7           Terry Golden & Hardwell - Art of Rave 106
# 8      Hardwell @ Mainstage, Mysteryland, Netherlands
# 9   Hardwell @ Mainstage, Lovestream Festival, Slo...
# 10        Hardwell @ Altromondo Studios Rimini, Italy
# 11  Hardwell @ Mainstage, Dreambeach Festival Vill...
# 12  Hardwell @ MEO Stage, Festival MEO Sudoeste, P...
# 13            Hardwell - Tomorrowland 2023 Aftermovie
# 14  Hardwell @ Mainstage, Tomorrowland Weekend 2, ...
# 15        Hardwell @ Mainstage, Parookaville, Germany
# ...

# %%
testezasso = pd.read_csv('testezasso.csv')
display(testezasso)
# Out:
#                                        Artista(s)                 Nome Música  \
# 0                                           Mau P        Drugs From Amsterdam
# 1             Tiësto & Solardo ft. Poppy Baskcomb                I Can't Wait
# 2         Gorillaz ft. Tame Impala & Bootie Brown  New Gold (Dom Dolla Remix)
# 3                Dom Dolla ft. Clementine Douglas               Miracle Maker
# 4                                           Jengi                   Bel Mercy
# 5                                       Supermode  Tell Me Why (MEDUZA Remix)
# 6                     Cedric Gervais & Joel Corry                       Molly
# 7   Fred again.. & Swedish House Mafia ft. Future  Turn On The Lights Again..
# 8                 Leandro Da Silva & Mimmo Errico                    Me Gusta
# 9                      HUGEL & BLOND:ISH & Nfasis                     Tra Tra
# 10                   James Hype & Miggy Dela Rosa                     Ferrari
# ...

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.colors import Normalize

# Normalizar os valores para o intervalo [0, 1]
norm = Normalize(vmin=min(testezasso['Suporte']), vmax=max(testezasso['Suporte']))

# Escolher um colormap, por exemplo, 'viridis'
cmap = cm.viridis

# Criar o gráfico de barras com cores variadas
fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(testezasso['Nome Música'], testezasso['Suporte'], color=cmap(norm(testezasso['Suporte'])))

# Adicionar rótulos e título
ax.set_xlabel('Nome da Música')
ax.set_ylabel('Suporte')
ax.set_title('Suporte por Música')

# Rotacionar os rótulos no eixo x para melhor ajuste
plt.xticks(rotation=90, ha='center')

# Adicionar barra de cores
sm = plt.cm.ScalarMappable(cmap=cmap, norm=norm)
sm.set_array([])
cbar = plt.colorbar(sm)

# Adicionar valores nas barras
for bar in bars:
    yval = bar.get_height()
    ax.text(bar.get_x() + bar.get_width()/2, yval + 0.05, round(yval, 2), ha='center', va='bottom')

# Exibir o gráfico
plt.tight_layout()
plt.show()
# Out:
# C:\Users\felip\AppData\Local\Temp\ipykernel_3636\3311031812.py:26: MatplotlibDeprecationWarning: Unable to determine Axes to steal space for Colorbar. Using gca(), but will raise in the future. Either provide the *cax* argument to use as the Axes for the Colorbar, provide the *ax* argument to steal space from it, or add *mappable* to an Axes.
#   cbar = plt.colorbar(sm)
