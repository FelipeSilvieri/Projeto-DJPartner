# %%
import pandas as pd

# %%
df = pd.read_csv('../artists_sets/lost_frequencies.csv')
df = df.sort_values(by='tracks_identificadas', ascending=False)

set_image = df.iloc[int(6)]['image_url']
# Exibir o resultado
display(df)
print(set_image)
# Out:
#                                                  name  \
# 2   MOGUAI & Lost Frequencies & Mau P + More - 1LI...
# 24  Armin van Buuren & Lost Frequencies - Dance De...
# 27  Lost Frequencies @ Horizon Stage, Creamfields ...
# 6     Lost Frequencies @ Peakstorm Festival, Malaysia
# 29  Lost Frequencies @ S2O Songkran Music Festival...
# 14             Lost Frequencies - Lost Radio Show 331
# 23             Lost Frequencies - Lost Radio Show 323
# 22             Lost Frequencies - Lost Radio Show 324
# 21             Lost Frequencies - Lost Radio Show 325
# 20             Lost Frequencies - Lost Radio Show 326
# 18  Lost Frequencies @ Mainstage, Tomorrowland Brasil
# 16             Lost Frequencies - Lost Radio Show 329
# 1              Lost Frequencies - Lost Radio Show 339
# 0              Lost Frequencies - Lost Radio Show 340
# 12             Lost Frequencies - Lost Radio Show 332
# 9              Lost Frequencies - Lost Radio Show 333
# ...
